# %% [markdown]
# ## Using the Provided HOG and Colour Histogram CSV Files as Input Into k-Nearest Neighbours for Classification
#
# This notebook contains code for a k-nearest neighbours algorithm which uses `hog_pca.csv` and `color_histogram.csv` as input. It also tests two different methodologies: scaling the `color_histogram.csv` data and not scaling at all.
#
# Accuracy for non-scaled peaked at 33.73%, and accuracy for scaled peaked at 22.27%.

# %%
from main import create_tier1_ft_df
from pipelines import test_k_vals

tier1_ft_df = create_tier1_ft_df()

k_values = [1, 2, 3, 4, 5, 7, 9, 11, 15, 20]

test_k_vals(tier1_ft_df, k_values, scale=True)
print("-" * 60)
test_k_vals(tier1_ft_df, k_values, scale=False)

# %%
from main import create_tier2_ft_df
from pipelines import test_k_vals

tier2_ft_df = create_tier2_ft_df()

k_values = [1, 2, 3, 4, 5, 7, 9, 11, 15, 20]


test_k_vals(tier2_ft_df, k_values, scale=True)
print("-" * 60)
test_k_vals(tier2_ft_df, k_values, scale=False)

# %%
from main import create_tier3_ft_df
from pipelines import test_k_vals

tier3_ft_df = create_tier3_ft_df()

k_values = [1, 2, 3, 4, 5, 7, 9, 11, 15, 20]


test_k_vals(tier3_ft_df, k_values, scale=True)
print("-" * 60)
test_k_vals(tier3_ft_df, k_values, scale=False)
# Out:
# Loading pre-trained ResNet...
# Starting RES feature extraction...
# Extracted 3700/3750 images...
# RES Extraction Complete!
# K-val: 1
# Testing 750 unseen images...
# Final accuracy: 0.7200
# K-val: 2
# Testing 750 unseen images...
# Final accuracy: 0.7493
# K-val: 3
# Testing 750 unseen images...
# Final accuracy: 0.7493
# K-val: 4
# Testing 750 unseen images...
# Final accuracy: 0.7587
# K-val: 5
# Testing 750 unseen images...
# Final accuracy: 0.7547
# K-val: 7
# Testing 750 unseen images...
# Final accuracy: 0.7560
# K-val: 9
# Testing 750 unseen images...
# Final accuracy: 0.7680
# K-val: 11
# Testing 750 unseen images...
# Final accuracy: 0.7733
# K-val: 15
# Testing 750 unseen images...
# Final accuracy: 0.7573
# K-val: 20
# Testing 750 unseen images...
# Final accuracy: 0.7427
# Best hyperparameters found!
# Best k: 11 | Accuracy: 0.773
# ------------------------------------------------------------
# K-val: 1
# Testing 750 unseen images...
# Final accuracy: 0.7280
# K-val: 2
# Testing 750 unseen images...
# Final accuracy: 0.7547
# K-val: 3
# Testing 750 unseen images...
# Final accuracy: 0.7547
# K-val: 4
# Testing 750 unseen images...
# Final accuracy: 0.7560
# K-val: 5
# Testing 750 unseen images...
# Final accuracy: 0.7587
# K-val: 7
# Testing 750 unseen images...
# Final accuracy: 0.7680
# K-val: 9
# Testing 750 unseen images...
# Final accuracy: 0.7667
# K-val: 11
# Testing 750 unseen images...
# Final accuracy: 0.7627
# K-val: 15
# Testing 750 unseen images...
# Final accuracy: 0.7653
# K-val: 20
# Testing 750 unseen images...
# Final accuracy: 0.7707
# Best hyperparameters found!
# Best k: 20 | Accuracy: 0.771
# (20, 0.7706666666666667)
