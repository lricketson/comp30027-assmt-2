# %% [markdown]
# ## Simple Neural Network

# %%
from main import create_tier1_ft_df
from pipelines import run_nn_grid_search

tier1_ft_df = create_tier1_ft_df()

learning_rates = [0.1, 0.2, 0.3, 0.4]
epoch_counts = [2500, 4000]
hidden_sizes = [32, 64, 128, 256]

best_hyperparams_tier1 = run_nn_grid_search(
    tier1_ft_df,
    learning_rates=learning_rates,
    epoch_counts=epoch_counts,
    hidden_sizes=hidden_sizes,
    ignore_scale_cols=["hog"],
)

# %%
from main import create_tier2_ft_df
from pipelines import run_nn_grid_search

tier2_ft_df = create_tier2_ft_df()

learning_rates = [0.1, 0.2, 0.3, 0.4]
epoch_counts = [2500, 4000]
hidden_sizes = [32, 64, 128, 256]

best_hyperparams_tier2 = run_nn_grid_search(
    tier2_ft_df,
    learning_rates=learning_rates,
    epoch_counts=epoch_counts,
    hidden_sizes=hidden_sizes,
    ignore_scale_cols=["hog"],
)

# %%
from main import create_tier3_ft_df
from pipelines import run_nn_grid_search

tier3_ft_df = create_tier3_ft_df()

learning_rates = [0.1, 0.2, 0.3, 0.4]
epoch_counts = [2500, 4000]
hidden_sizes = [32, 64, 128, 256]

best_hyperparams_tier3 = run_nn_grid_search(
    tier3_ft_df,
    learning_rates=learning_rates,
    epoch_counts=epoch_counts,
    hidden_sizes=hidden_sizes,
    ignore_scale_cols=["hog"],
)
# Out:
# Loading pre-trained ResNet...
# Starting RES feature extraction...
# Extracted 3700/3750 images...
# RES Extraction Complete!
#
# Starting search for best hyperparameters...
# Grid Search Progress: 0.00% complete
# ---> New best! Accuracy: 83.50% | LR: 0.1, Epochs: 2500, HS: 32
# Grid Search Progress: 3.12% complete
# ---> New best! Accuracy: 84.33% | LR: 0.1, Epochs: 2500, HS: 64
# Grid Search Progress: 34.38% complete
