# %% [markdown]
# ## Simple Neural Network

# %%
### SETUP CELL - RUN ME ONCE
from evaluation import evaluate_nn_tier
from preprocessing import create_tier1_ft_df, create_tier2_ft_df, create_tier3_ft_df
from constants import TASK1_DATA, TIER_1, TIER_2, TIER_3

learning_rates = [0.1, 0.2, 0.3, 0.4]
epoch_counts = [2500, 4000]
hidden_sizes = [32, 64, 128, 256]

save_path = "./plots/"

# %%
tier1_data_df = create_tier1_ft_df(task_folder=TASK1_DATA)
evaluate_nn_tier(
    feature_df=tier1_data_df,
    learning_rates=learning_rates,
    epoch_counts=epoch_counts,
    hidden_sizes=hidden_sizes,
    tier_name=TIER_1,
    save_path=save_path,
)
# Out:
# ========== Evaluating TIER 1 ==========
#
# Starting search for best hyperparameters...
# Grid Search Progress: 0.00% complete
# ---> New best! Accuracy: 52.13% | LR: 0.1, Epochs: 2500, HS: 32
# Grid Search Progress: 3.12% complete
# ---> New best! Accuracy: 53.73% | LR: 0.1, Epochs: 2500, HS: 64
# Grid Search Progress: 6.25% complete
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 tier1_data_df = create_tier1_ft_df(task_folder=TASK1_DATA)
# ----> 2 evaluate_nn_tier(
#       3     feature_df=tier1_data_df,
#       4     learning_rates=learning_rates,
#       5     epoch_counts=epoch_counts,
#       6     hidden_sizes=hidden_sizes,
#       7     tier_name=TIER_1,
#       8     save_path=save_path,
#       9 )
#
# File c:\Users\liamr\python-work\COMP30027-ML\assignments\ml-assmt-2\evaluation.py:70, in evaluate_nn_tier(feature_df, learning_rates, epoch_counts, hidden_sizes, tier_name, save_path)
#      67 """Runs the NN grid search and automatically plots the matrix."""
#      68 print(f"\n========== Evaluating {tier_name.upper()} ==========")
# ---> 70 best_hp, best_model, y_val, y_pred = run_nn_grid_search(
#      71     feature_df,
#      72     learning_rates,
#      73     epoch_counts,
#      74     hidden_sizes,
#      75     ignore_scale_cols=["hog"],
#      76 )
#      78 unique_classes = sorted(y_val.unique())
#      79 plot_title = f"Neural Network - {tier_name}"
#
# File c:\Users\liamr\python-work\COMP30027-ML\assignments\ml-assmt-2\pipelines.py:130, in run_nn_grid_search(feature_df, learning_rates, epoch_counts, hidden_sizes, ignore_scale_cols)
#     124 proportion_completed = tests_completed / total_num_tests
#     125 print(
#     126     f"Grid Search Progress: {100 * proportion_completed:.2f}% complete",
#     127     end="\r",
#     128 )
# --> 130 params_dict = train_network(
#     131     X=X_train_scaled,
#     132     hidden_size=hidden_size,
#     133     output_size=len(unique_classes),
#     134     epochs=epoch_count,
#     135     Y=y_train_ohe,
#     136     learning_rate=learning_rate,
#     137 )
#     139 predictions, probs = make_prediction(
#     140     X=X_val_scaled,
#     141     classes_array=unique_classes,
#     142     params_dict=params_dict,
#     143 )
#     145 accuracy = calculate_accuracy(preds=predictions, true_labels=y_val)
#
# File c:\Users\liamr\python-work\COMP30027-ML\assignments\ml-assmt-2\nn_util.py:116, in train_network(X, hidden_size, output_size, epochs, Y, learning_rate, print_progress)
#     112 params_dict = initialise_params(
#     113     input_size=input_size, hidden_size=hidden_size, output_size=output_size
#     114 )
#     115 for i in range(epochs + 1):
# --> 116     A2, cache_dict = forward_pass(params_dict=params_dict, X=X)
#     117     loss = compute_loss(A2, Y)
#     118     gradients_dict = backward_pass(X, Y, cache_dict, params_dict)
#
# File c:\Users\liamr\python-work\COMP30027-ML\assignments\ml-assmt-2\nn_util.py:29, in forward_pass(X, params_dict)
#      26 Z1 = np.dot(X, W1) + b1
#      28 # run ReLU
# ---> 29 A1 = np.maximum(Z1, 0)
#      31 Z2 = np.dot(A1, W2) + b2
#      33 # exponentiate for making sure all numbers are positive while still preserving order
#      34 # (because of monotonicity of the exponential)
#
# KeyboardInterrupt:

# %%
tier2_data_df = create_tier2_ft_df(task_folder=TASK1_DATA)
evaluate_nn_tier(
    feature_df=tier2_data_df,
    learning_rates=learning_rates,
    epoch_counts=epoch_counts,
    hidden_sizes=hidden_sizes,
    tier_name=TIER_2,
    save_path=save_path,
)

# %%
tier3_data_df = create_tier3_ft_df(task_folder=TASK1_DATA)
evaluate_nn_tier(
    feature_df=tier3_data_df,
    learning_rates=learning_rates,
    epoch_counts=epoch_counts,
    hidden_sizes=hidden_sizes,
    tier_name=TIER_3,
    save_path=save_path,
)
