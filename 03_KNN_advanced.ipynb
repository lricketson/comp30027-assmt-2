# %% [markdown]
# ## Using a Pre-Trained Neural Network to Extract Features, Which Are Then Handed Off to K-Nearest Neighbours for Classification
#
# This model uses a ResNet Neural Network pretrained on ImageNet data to extract numerical features, and then hands off those extracted features to a K-Nearest Neighbours algorithm for classification.
