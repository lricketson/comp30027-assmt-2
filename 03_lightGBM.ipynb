# %%
from preprocessing import create_tier1_ft_df
from pipelines import run_lgbm_grid_search
from constants import TASK2_DATA

tier1_ft_df = create_tier1_ft_df(TASK2_DATA)

learning_rates = [0.01, 0.05, 0.1, 0.2]
max_depths = [3, 5, 7]  # how many questions a tree can ask before it guesses
n_estimators_list = [50, 100, 200]  # number of trees in forest

run_lgbm_grid_search(
    feature_df=tier1_ft_df,
    learning_rates=learning_rates,
    max_depths=max_depths,
    n_estimators_list=n_estimators_list,
)

# %%
from preprocessing import create_tier2_ft_df
from pipelines import run_lgbm_grid_search
from constants import TASK2_DATA

tier2_ft_df = create_tier2_ft_df(task_folder=TASK2_DATA)

learning_rates = [0.01, 0.05, 0.1, 0.2]
max_depths = [3, 5, 7]  # how many questions a tree can ask before it guesses
n_estimators_list = [50, 100, 200]  # number of trees in forest

run_lgbm_grid_search(
    feature_df=tier2_ft_df,
    learning_rates=learning_rates,
    max_depths=max_depths,
    n_estimators_list=n_estimators_list,
)

# %%
from preprocessing import create_tier3_ft_df
from pipelines import run_lgbm_grid_search
from constants import TASK2_DATA

tier3_ft_df = create_tier3_ft_df(task_folder=TASK2_DATA)

learning_rates = [0.01, 0.05, 0.1, 0.2]
max_depths = [3, 5, 7]  # how many questions a tree can ask before it guesses
n_estimators_list = [50, 100, 200]  # number of trees in forest

run_lgbm_grid_search(
    feature_df=tier3_ft_df,
    learning_rates=learning_rates,
    max_depths=max_depths,
    n_estimators_list=n_estimators_list,
)
