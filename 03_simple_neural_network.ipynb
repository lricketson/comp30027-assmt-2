# %% [markdown]
# ## Simple Neural Network

# %%
import pandas as pd
from main import create_hog_colour_df

colour_hog_df = create_hog_colour_df()

print(colour_hog_df.head())
print(colour_hog_df.shape)
