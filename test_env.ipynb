# %%
from main import scale_data, create_tier1_ft_df, create_tier2_ft_df

tier1_ft_df = create_tier1_ft_df()

print(tier1_ft_df.head())
print(len(tier1_ft_df.columns))

tier2_ft_df = create_tier2_ft_df()

print("---" * 20)

print(tier2_ft_df.head())
print(len(tier2_ft_df.columns))
print([col for col in tier2_ft_df.columns if "lbp" in col])
# Out:
#            image_id    feat_0      feat_1    feat_2    feat_3    feat_4  \
# 0  train_bird_00000  0.122559  128.123927  0.525404  0.496788  0.424831
# 1  train_bird_00001  0.111084  159.237911  0.581840  0.469095  0.320754
# 2  train_bird_00002  0.057617  105.335205  0.483975  0.446298  0.334521
# 3  train_bird_00003  0.082520  101.761614  0.472897  0.416837  0.346319
# 4  train_bird_00004  0.045410   72.025203  0.534991  0.554441  0.429859
#
#      feat_5    feat_6    feat_7    feat_8  ...  hog_pca_93  hog_pca_94  \
# 0  0.497121  0.119286  0.363093  0.106975  ...    0.001760   -0.013955
# 1  0.485914  0.214456  0.424178  0.259658  ...    0.083025    0.009925
# 2  0.444767  0.084327  0.382651  0.087305  ...   -0.050535   -0.026171
# 3  0.425581  0.181981  0.382586  0.183532  ...   -0.018244   -0.073181
# 4  0.534472  0.181864  0.364934  0.193419  ...    0.259495   -0.005557
#
#    hog_pca_95  hog_pca_96  hog_pca_97  hog_pca_98  hog_pca_99  \
# ...
