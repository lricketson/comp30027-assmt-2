# %%
from preprocessing import create_tier1_ft_df
from constants import TASK1_DATA

df = create_tier1_ft_df(task_folder=TASK1_DATA)

print(df.loc[13, :])
# Out:
# image_id                      train_bird_00013
# feat_0                                0.030518
# feat_1                               21.891111
# feat_2                                0.295658
# feat_3                                0.454688
#                             ...
# hog_pca_98                            0.157781
# hog_pca_99                           -0.087543
# image_path    images/train/bird/bird_00013.png
# class_id                                     0
# class_name                                bird
# Name: 13, Length: 223, dtype: object
